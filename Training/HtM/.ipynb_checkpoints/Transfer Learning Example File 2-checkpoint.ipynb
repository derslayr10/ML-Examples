# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools
import random
import os

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.utils import *

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
df1 = pd.read_csv("HtM_MAF Data_Final_Edited.csv", usecols = ["Corrosion", "Bare Metal", "Corrosion Prevention Treatment", "Routine Maintenance" , "Unscheduled Maintenance" , "Mission-Related Maintenance" , "Failure"])

#create encoder to easily shape data
labelEncoder = LabelEncoder()

#encode labels
df1["Corrosion"] = labelEncoder.fit_transform(df1["Corrosion"])
df1["Bare Metal"] = labelEncoder.fit_transform(df1["Bare Metal"])
df1["Corrosion Prevention Treatment"] = labelEncoder.fit_transform(df1["Corrosion Prevention Treatment"])
df1["Routine Maintenance"] = labelEncoder.fit_transform(df1["Routine Maintenance"])
df1["Unscheduled Maintenance"] = labelEncoder.fit_transform(df1["Unscheduled Maintenance"])
df1["Mission-Related Maintenance"] = labelEncoder.fit_transform(df1["Mission-Related Maintenance"])
df1["Failure"] = labelEncoder.fit_transform(df1["Failure"])

#create train and test sets
Train1 = pd.DataFrame(data = df1, columns = ["Bare Metal", "Corrosion Prevention Treatment", "Routine Maintenance" , "Unscheduled Maintenance" , "Mission-Related Maintenance" , "Failure"], copy = True)
Test1 = pd.DataFrame(data = df1, columns = ["Corrosion"], copy = True)

#create train and test data
train_features1, test_features1, train_labels1, test_labels1 = train_test_split(Train1, Test1, test_size = 0.25, random_state = random.seed(1))

# %%
print("Train Features shape: ", train_features1.shape)
print("Train Labels shape: ", train_labels1.shape)
print("Test Features shape: ", test_features1.shape)
print("Test Labels shape: ", test_labels1.shape)
# Out:
# Train Features shape:  (271710, 6)
# Train Labels shape:  (271710, 1)
# Test Features shape:  (90571, 6)
# Test Labels shape:  (90571, 1)

# %%
model = load_model('tl_example_2.h5')
layer_list = list()
for layer in model.layers[1:]:
    layer.trainable = False
    layer_list.append(layer)
print(len(layer_list))
# Out:
# 16

# %%
model1 = Sequential()
model1.add(Dense(32, input_dim = train_features1.shape[1], activation = "relu", name = "layer1"))
model1.add(Dense(32, activation = "relu", name = "layer2"))
model1.add(Dropout(0.3))
model1.add(Dense(32, activation = "relu", name = "layer3"))
model1.add(Dropout(0.2))
model1.add(Dense(32, activation = "relu", name = "layer4"))
model1.add(Dropout(0.1))
model1.add(Dense(32, activation = "relu", name = "layer5"))
model1.add(Dense(32, activation = "relu", name = "layer6"))
model1.add(Dropout(0.2))
model1.add(Dense(32, activation = "relu", name = "layer7"))
model1.add(Dropout(0.3))
model1.add(Dense(32, activation = "relu", name = "layer8"))
model1.add(Dropout(0.1))
model1.add(Dense(32, activation = "relu", name = "layer9"))
model1.add(Dropout(0.2))
model1.add(Dense(32, activation = "relu", name = "layer10"))
model1.add(Dropout(0.2))
model1.add(Dense(32, activation = "relu", name = "layer11"))
model1.add(Dropout(0.2))
model1.add(Dense(32, activation = "relu", name = "layer12"))
model1.add(Dropout(0.1))
model1.add(layer_list[0])
model1.add(Dropout(0.1))
model1.add(layer_list[1])
model1.add(Dropout(0.1))
model1.add(layer_list[2])
model1.add(Dropout(0.1))
model1.add(layer_list[3])
model1.add(layer_list[4])
model1.add(layer_list[5])
model1.add(layer_list[6])
model1.add(layer_list[7])
model1.add(layer_list[8])
model1.add(Dropout(0.2))
model1.add(layer_list[9])
model1.add(Dropout(0.2))
model1.add(layer_list[10])
model1.add(Dropout(0.2))
model1.add(layer_list[11])
model1.add(Dropout(0.1))
model1.add(layer_list[12])
model1.add(Dropout(0.1))
model1.add(layer_list[13])
model1.add(Dropout(0.1))
model1.add(layer_list[14])
model1.add(Dropout(0.1))
model1.add(layer_list[15])

model1.compile(loss = "binary_crossentropy", optimizer = "adadelta", metrics = ["accuracy"])

model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 32)                224
# _________________________________________________________________
# layer2 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer3 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer4 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer5 (Dense)               (None, 32)                1056
# _________________________________________________________________
# layer6 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer7 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer8 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer9 (Dense)               (None, 32)                1056
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer10 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer11 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 32)                0
# _________________________________________________________________
# layer12 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                990
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 28)                868
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 28)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 26)                754
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 26)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                648
# _________________________________________________________________
# dense_5 (Dense)              (None, 22)                550
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                460
# _________________________________________________________________
# dense_7 (Dense)              (None, 18)                378
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                304
# _________________________________________________________________
# dense_9 (Dense)              (None, 14)                238
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 14)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 12)                180
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                130
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 28
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 4)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 2)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 17,523
# Trainable params: 11,840
# Non-trainable params: 5,683
# _________________________________________________________________

# %%
history = model1.fit(train_features1, train_labels1, batch_size = 30, epochs = 200)
# Out:
# Epoch 1/200
# 9057/9057 [==============================] - 80s 9ms/step - loss: 2.3089 - accuracy: 0.0643
# Epoch 2/200
# 9057/9057 [==============================] - 76s 8ms/step - loss: 2.3074 - accuracy: 0.0648
# Epoch 3/200
# 9057/9057 [==============================] - 80s 9ms/step - loss: 2.3072 - accuracy: 0.0656
# Epoch 4/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 2.3082 - accuracy: 0.0647
# Epoch 5/200
# 9057/9057 [==============================] - 73s 8ms/step - loss: 2.3042 - accuracy: 0.0654
# Epoch 6/200
# 9057/9057 [==============================] - 73s 8ms/step - loss: 2.3046 - accuracy: 0.0656
# Epoch 7/200
# 9057/9057 [==============================] - 73s 8ms/step - loss: 2.3013 - accuracy: 0.0670 0s - loss: 2.3013 - accuracy
# Epoch 8/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 2.2957 - accuracy: 0.0696
# Epoch 9/200
# 9057/9057 [==============================] - 73s 8ms/step - loss: 2.2655 - accuracy: 0.0798
# Epoch 10/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 2.0181 - accuracy: 0.1763
# Epoch 11/200
# 9057/9057 [==============================] - 73s 8ms/step - loss: 1.3192 - accuracy: 0.4647
# Epoch 12/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 1.0445 - accuracy: 0.5900
# Epoch 13/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9753 - accuracy: 0.6212
# Epoch 14/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9481 - accuracy: 0.6349
# Epoch 15/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9362 - accuracy: 0.6416
# Epoch 16/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9300 - accuracy: 0.6466
# Epoch 17/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9301 - accuracy: 0.6484
# Epoch 18/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9236 - accuracy: 0.6521
# Epoch 19/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9245 - accuracy: 0.6510
# Epoch 20/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9191 - accuracy: 0.6548
# Epoch 21/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9119 - accuracy: 0.6577
# Epoch 22/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9078 - accuracy: 0.6591
# Epoch 23/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9117 - accuracy: 0.6585
# Epoch 24/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.9151 - accuracy: 0.6595
# Epoch 25/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8988 - accuracy: 0.6665
# Epoch 26/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8915 - accuracy: 0.6700
# Epoch 27/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8900 - accuracy: 0.6705
# Epoch 28/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8747 - accuracy: 0.6780
# Epoch 29/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8573 - accuracy: 0.6849
# Epoch 30/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8498 - accuracy: 0.6873
# Epoch 31/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.8231 - accuracy: 0.6941
# Epoch 32/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.7813 - accuracy: 0.7026
# Epoch 33/200
# 9057/9057 [==============================] - 77s 8ms/step - loss: 0.7146 - accuracy: 0.7189
# Epoch 34/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6853 - accuracy: 0.7277
# Epoch 35/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6800 - accuracy: 0.7307
# Epoch 36/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6679 - accuracy: 0.7365
# Epoch 37/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6749 - accuracy: 0.7373
# Epoch 38/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6642 - accuracy: 0.7413
# Epoch 39/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6640 - accuracy: 0.7433
# Epoch 40/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6629 - accuracy: 0.7447
# Epoch 41/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6665 - accuracy: 0.7455
# Epoch 42/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6533 - accuracy: 0.7499
# Epoch 43/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6592 - accuracy: 0.7482
# Epoch 44/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6485 - accuracy: 0.7528
# Epoch 45/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6668 - accuracy: 0.7496
# Epoch 46/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6637 - accuracy: 0.7514
# Epoch 47/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6662 - accuracy: 0.7518
# Epoch 48/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6584 - accuracy: 0.7533
# Epoch 49/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6547 - accuracy: 0.7542
# Epoch 50/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6610 - accuracy: 0.7532
# Epoch 51/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6513 - accuracy: 0.7551
# Epoch 52/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6461 - accuracy: 0.7567
# Epoch 53/200
# 9057/9057 [==============================] - 76s 8ms/step - loss: 0.6526 - accuracy: 0.7577
# Epoch 54/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6656 - accuracy: 0.7541
# Epoch 55/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6700 - accuracy: 0.7538
# Epoch 56/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6721 - accuracy: 0.7554
# Epoch 57/200
# 9057/9057 [==============================] - 76s 8ms/step - loss: 0.6622 - accuracy: 0.7572
# Epoch 58/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6675 - accuracy: 0.7546
# Epoch 59/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6730 - accuracy: 0.7562
# Epoch 60/200
# 9057/9057 [==============================] - 74s 8ms/step - loss: 0.6682 - accuracy: 0.7576
# Epoch 61/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6636 - accuracy: 0.7571
# Epoch 62/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6836 - accuracy: 0.7569
# Epoch 63/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6661 - accuracy: 0.7565
# Epoch 64/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6689 - accuracy: 0.7573
# Epoch 65/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6607 - accuracy: 0.7596
# Epoch 66/200
# 9057/9057 [==============================] - 75s 8ms/step - loss: 0.6716 - accuracy: 0.7582
# Epoch 67/200
# 9057/9057 [==============================] - 78s 9ms/step - loss: 0.6829 - accuracy: 0.7571
# Epoch 68/200
# 2785/9057 [========>.....................] - ETA: 1:05 - loss: 0.6727 - accuracy: 0.7544
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e4bd51b8553f> in <module>
# ----> 1 history = model1.fit(train_features1, train_labels1, batch_size = 30, epochs = 200)
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# F:\Anaconda\Anaconda\envs\research_examples\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
